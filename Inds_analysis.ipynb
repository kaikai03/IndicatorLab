# %%
from qaenv import  mongo_ip
import pymongo
import numpy as np
import uuid
import copy
import pandas as pd


import QUANTAXIS as QA
from QUANTAXIS.QAARP import QA_Risk, QA_User
from QUANTAXIS.QAEngine.QAThreadEngine import QA_Thread
from QUANTAXIS.QAUtil.QAParameter import MARKET_TYPE, RUNNING_ENVIRONMENT, ORDER_DIRECTION


import Ind_MACD_JCSC

# %load_ext autoreload
# %autoreload 1
# %aimport Ind_MACD_JCSC


class Analysis:
    def __init__(self, code_list=['000001'], frequence='day', strategy_id='x', portfolio='default',
                 start='2020-01-01', end='2020-05-21', init_cash=1000000, 
                 taskid=None, mongo_ip=mongo_ip, model='py'):
        self.username = 'admin'
        self.password = 'admin'

        self.code_list = code_list
        self.frequence = frequence
        self.strategy_id = strategy_id

        self.portfolio = portfolio

        self.start = start
        self.end = end
        self.init_cash = init_cash
        self.taskid = taskid

        self.running_time = ''

        self.model = model
        self.bar_order = {}
        self._market_data = []
        
        self.running_mode = 'backtest'
        self.market_type = MARKET_TYPE.STOCK_CN
        
        self.accounts = {}
        self.running_time = {}
        self.indicators = None
        
        self.alldata = None

    @property
    def bar_id(self):
        return len(self._market_data)
    
    @property
    def acc_portfolio(self):
        if self.accounts.get('portfolio',None) == None:
            raise Exception('需要先执行debug_portfolio')
        return self.accounts['portfolio']
        
    def debug_portfolio(self, is_hfq=False):
        self.database = pymongo.MongoClient(mongo_ip).QUANTAXIS
        user = QA_User(username="admin", password='admin')
        port = user.new_portfolio(self.portfolio)
        self.accounts['portfolio'] = port.new_accountpro(
            account_cookie=self.strategy_id, init_cash=self.init_cash, 
            market_type=self.market_type, frequence= self.frequence)

        data = QA.QA_quotation(self.code_list, self.start, self.end, source=QA.DATASOURCE.MONGO,
                               frequence=self.frequence, market=self.market_type, 
                               output=QA.OUTPUT_FORMAT.DATASTRUCT)
        if is_hfq:
            data = data.to_hfq()
        
        self.alldata = data
        self.indicators = self.on_indicators_preparing(data)

        
        data.data.apply(self.x1_portfolio, axis=1)
        
        
    def x1_portfolio(self, item):
        if self.running_time.get(item.name[1], None) != None:
            if str(item.name[0])[0:10] != str(self.running_time[item.name[1]])[0:10]:
                self.on_dailyclose()
                print('backtest: Settle!')
                self.accounts['portfolio'].settle()
                self.on_dailyopen()
        self._market_data.append(copy.deepcopy(item))
        self.running_time[item.name[1]] = str(item.name[0])
        self.on_bar(item, self.accounts['portfolio'])
                
    def on_dailyclose(self):
        pass
    def on_dailyopen(self):
        pass
    def on_bar(self, bar, account):
        raise NotImplementedError
        
    def on_indicators_preparing(self, data):
        raise NotImplementedError
        
            
        
    def send_order(self,account, direction='BUY', code=None, price=3925, volume=10, order_id=''):
        towards = direction
        order_id = str(uuid.uuid4()) if order_id == '' else order_id

        if towards == 'BUY':
            towards = ORDER_DIRECTION.BUY
        elif towards == 'SELL':
            towards = ORDER_DIRECTION.SELL

        if isinstance(price, float):
            pass
        elif isinstance(price, pd.Series):
            price = price.values[0]
    
        self.bar_order['{}_{}'.format(code, direction)] = self.bar_id

        account.receive_simpledeal(
            code=code, trade_time=self.running_time[code], trade_towards=towards, trade_amount=volume, trade_price=price, order_id=order_id)
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
class test(Analysis):
    def on_indicators_preparing(self, data):
        print(type(data))
        MACD = Ind_MACD_JCSC.MACD(data)
        MACD.fit()
        return MACD.ind
        
    def on_bar(self, bar, acc):
        current_code = bar.name[1]

        res = self.randddd(current_code)
        print(res)
        print(acc.cash_available)
        print(res)
        print(bar.name[0],current_code)
        print(self.indicators.get_ind(current_code,bar.name[0]))
        
        if res > 5:
            print('LONG',current_code, acc.get_position(current_code).volume_long)
            self.send_order(acc, 'BUY', price=bar['close'], volume=10000, code= current_code)
        else:
            print('SHORT',current_code, acc.get_position(current_code).volume_long)
            if acc.get_position(current_code).volume_long > 0:
                self.send_order(acc, 'SELL', price=bar['close'], volume=10000, code= current_code)

    def randddd(self, code):
        return np.random.randint(0,9)

# %%
# %%time
t = test(code_list=['000001', '000002'], frequence='day', start='2019-08-01', end='2019-09-01', strategy_id='x')
t.debug_portfolio(is_hfq=True)
# Out:
#  prortfolio with user_cookie  USER_u8pObTlF  already exist!!
# QAACCPRO: reload from DATABASE
# {}
# <class 'QUANTAXIS.QAData.QADataStruct.QA_DataStruct_Stock_day'>
# 5
# 1000000
# 5
# 2019-08-01 00:00:00 000001
# DIFF        NaN
# DEA         NaN
# MACD        NaN
# CROSS_JC    0.0
# CROSS_SC    0.0
# ZERO        0.0
# Name: (2019-08-01 00:00:00, 000001), dtype: float64
# SHORT 000001 0
# 1
# 1000000
# 1
# 2019-08-01 00:00:00 000002
# DIFF        NaN
# DEA         NaN
# MACD        NaN
# CROSS_JC    0.0
# CROSS_SC    0.0
# ZERO        0.0
# Name: (2019-08-01 00:00:00, 000002), dtype: float64
# SHORT 000002 0
# backtest: Settle!
# 0
# 1000000
# 0
# 2019-08-02 00:00:00 000001
# DIFF        NaN
# DEA         NaN
# MACD        NaN
# CROSS_JC    0.0
# CROSS_SC    0.0
# ZERO        0.0
# Name: (2019-08-02 00:00:00, 000001), dtype: float64
# SHORT 000001 0
# backtest: Settle!
# 1
# 1000000
# 1
# 2019-08-02 00:00:00 000002
# DIFF        NaN
# DEA         NaN
# MACD        NaN
# CROSS_JC    0.0
# CROSS_SC    0.0
# ZERO        0.0
# Name: (2019-08-02 00:00:00, 000002), dtype: float64
# SHORT 000002 0
# backtest: Settle!
# 6
# 1000000
# 6
# 2019-08-05 00:00:00 000001
# DIFF        NaN
# DEA         NaN
# MACD        NaN
# CROSS_JC    0.0
# CROSS_SC    0.0
# ZERO        0.0
# Name: (2019-08-05 00:00:00, 000001), dtype: float64
# LONG 000001 0
# backtest: Settle!
# 7
# 866466.625
# 7
# 2019-08-05 00:00:00 000002
# DIFF        NaN
# DEA         NaN
# MACD        NaN
# CROSS_JC    0.0
# CROSS_SC    0.0
# ZERO        0.0
# Name: (2019-08-05 00:00:00, 000002), dtype: float64
# LONG 000002 0
# backtest: Settle!
# 7
# 596299.1
# 7
# 2019-08-06 00:00:00 000001
# DIFF        NaN
# DEA         NaN
# MACD        NaN
# CROSS_JC    0.0
# CROSS_SC    0.0
# ZERO        0.0
# Name: (2019-08-06 00:00:00, 000001), dtype: float64
# LONG 000001 10000
# backtest: Settle!
# 8
# 462565.675
# 8
# 2019-08-06 00:00:00 000002
# DIFF        NaN
# DEA         NaN
# MACD        NaN
# CROSS_JC    0.0
# CROSS_SC    0.0
# ZERO        0.0
# Name: (2019-08-06 00:00:00, 000002), dtype: float64
# LONG 000002 10000
# backtest: Settle!
# 7
# 192298.12500000006
# 7
# 2019-08-07 00:00:00 000001
# DIFF        NaN
# DEA         NaN
# MACD        NaN
# CROSS_JC    0.0
# CROSS_SC    0.0
# ZERO        0.0
# Name: (2019-08-07 00:00:00, 000001), dtype: float64
# LONG 000001 20000
# backtest: Settle!
# 1
# 56864.27500000006
# 1
# 2019-08-07 00:00:00 000002
# DIFF        NaN
# DEA         NaN
# MACD        NaN
# CROSS_JC    0.0
# CROSS_SC    0.0
# ZERO        0.0
# Name: (2019-08-07 00:00:00, 000002), dtype: float64
# SHORT 000002 20000
# backtest: Settle!
# 7
# 330122.275
# 7
# 2019-08-08 00:00:00 000001
# DIFF        NaN
# DEA         NaN
# MACD        NaN
# CROSS_JC    0.0
# CROSS_SC    0.0
# ZERO        0.0
# Name: (2019-08-08 00:00:00, 000001), dtype: float64
# LONG 000001 30000
# backtest: Settle!
# 8
# 186286.32499999998
# 8
# 2019-08-08 00:00:00 000002
# DIFF        NaN
# DEA         NaN
# MACD        NaN
# CROSS_JC    0.0
# CROSS_SC    0.0
# ZERO        0.0
# Name: (2019-08-08 00:00:00, 000002), dtype: float64
# LONG 000002 10000
# ALERT MONEY NOT ENOUGH!!!
# 186286.32499999998
# backtest: Settle!
# 5
# 186286.32499999998
# 5
# 2019-08-09 00:00:00 000001
# DIFF        NaN
# DEA         NaN
# MACD        NaN
# CROSS_JC    0.0
# CROSS_SC    0.0
# ZERO        0.0
# Name: (2019-08-09 00:00:00, 000001), dtype: float64
# SHORT 000001 40000
# backtest: Settle!
# 4
# 331304.825
# 4
# 2019-08-09 00:00:00 000002
# DIFF        NaN
# DEA         NaN
# MACD        NaN
# CROSS_JC    0.0
# CROSS_SC    0.0
# ZERO        0.0
# Name: (2019-08-09 00:00:00, 000002), dtype: float64
# SHORT 000002 10000
# backtest: Settle!
# 2
# 603863.7
# 2
# 2019-08-12 00:00:00 000001
# DIFF        NaN
# DEA         NaN
# MACD        NaN
# CROSS_JC    0.0
# CROSS_SC    0.0
# ZERO        0.0
# Name: (2019-08-12 00:00:00, 000001), dtype: float64
# SHORT 000001 30000
# backtest: Settle!
# 2
# 754874.7
# 2
# 2019-08-12 00:00:00 000002
# DIFF        NaN
# DEA         NaN
# MACD        NaN
# CROSS_JC    0.0
# CROSS_SC    0.0
# ZERO        0.0
# Name: (2019-08-12 00:00:00, 000002), dtype: float64
# SHORT 000002 0
# backtest: Settle!
# 5
# 754874.7
# 5
# 2019-08-13 00:00:00 000001
# DIFF        NaN
# DEA         NaN
# MACD        NaN
# CROSS_JC    0.0
# CROSS_SC    0.0
# ZERO        0.0
# Name: (2019-08-13 00:00:00, 000001), dtype: float64
# SHORT 000001 20000
# backtest: Settle!
# 3
# 903588.575
# 3
# 2019-08-13 00:00:00 000002
# DIFF        NaN
# DEA         NaN
# MACD        NaN
# CROSS_JC    0.0
# CROSS_SC    0.0
# ZERO        0.0
# Name: (2019-08-13 00:00:00, 000002), dtype: float64
# SHORT 000002 0
# backtest: Settle!
# 6
# 903588.575
# 6
# 2019-08-14 00:00:00 000001
# DIFF        NaN
# DEA         NaN
# MACD        NaN
# CROSS_JC    0.0
# CROSS_SC    0.0
# ZERO        0.0
# Name: (2019-08-14 00:00:00, 000001), dtype: float64
# LONG 000001 10000
# backtest: Settle!
# 4
# 753851.1499999999
# 4
# 2019-08-14 00:00:00 000002
# DIFF        NaN
# DEA         NaN
# MACD        NaN
# CROSS_JC    0.0
# CROSS_SC    0.0
# ZERO        0.0
# Name: (2019-08-14 00:00:00, 000002), dtype: float64
# SHORT 000002 0
# backtest: Settle!
# 3
# 753851.1499999999
# 3
# 2019-08-15 00:00:00 000001
# DIFF        NaN
# DEA         NaN
# MACD        NaN
# CROSS_JC    0.0
# CROSS_SC    0.0
# ZERO        0.0
# Name: (2019-08-15 00:00:00, 000001), dtype: float64
# SHORT 000001 20000
# backtest: Settle!
# 7
# 903064.3999999999
# 7
# 2019-08-15 00:00:00 000002
# DIFF        NaN
# DEA         NaN
# MACD        NaN
# CROSS_JC    0.0
# CROSS_SC    0.0
# ZERO        0.0
# Name: (2019-08-15 00:00:00, 000002), dtype: float64
# LONG 000002 0
# backtest: Settle!
# 4
# 629042.6837909336
# 4
# 2019-08-16 00:00:00 000001
# DIFF        NaN
# DEA         NaN
# MACD        NaN
# CROSS_JC    0.0
# CROSS_SC    0.0
# ZERO        0.0
# Name: (2019-08-16 00:00:00, 000001), dtype: float64
# SHORT 000001 10000
# backtest: Settle!
# 0
# 777856.4337909336
# 0
# 2019-08-16 00:00:00 000002
# DIFF        NaN
# DEA         NaN
# MACD        NaN
# CROSS_JC    0.0
# CROSS_SC    0.0
# ZERO        0.0
# Name: (2019-08-16 00:00:00, 000002), dtype: float64
# SHORT 000002 10000
# backtest: Settle!
# 7
# 1050843.9609636883
# 7
# 2019-08-19 00:00:00 000001
# DIFF       -0.137122
# DEA              NaN
# MACD             NaN
# CROSS_JC    0.000000
# CROSS_SC    0.000000
# ZERO        0.000000
# Name: (2019-08-19 00:00:00, 000001), dtype: float64
# LONG 000001 0
# backtest: Settle!
# 7
# 901606.6609636883
# 7
# 2019-08-19 00:00:00 000002
# DIFF        0.394372
# DEA              NaN
# MACD             NaN
# CROSS_JC    0.000000
# CROSS_SC    0.000000
# ZERO        0.000000
# Name: (2019-08-19 00:00:00, 000002), dtype: float64
# LONG 000002 0
# backtest: Settle!
# 6
# 621967.1874747094
# 6
# 2019-08-20 00:00:00 000001
# DIFF       -0.115252
# DEA              NaN
# MACD             NaN
# CROSS_JC    0.000000
# CROSS_SC    0.000000
# ZERO        0.000000
# Name: (2019-08-20 00:00:00, 000001), dtype: float64
# LONG 000001 10000
# backtest: Settle!
# 0
# 472029.7124747094
# 0
# 2019-08-20 00:00:00 000002
# DIFF        0.437487
# DEA              NaN
# MACD             NaN
# CROSS_JC    0.000000
# CROSS_SC    0.000000
# ZERO        0.000000
# Name: (2019-08-20 00:00:00, 000002), dtype: float64
# SHORT 000002 10000
# backtest: Settle!
# 6
# 754262.2510319296
# 6
# 2019-08-21 00:00:00 000001
# DIFF       -0.131749
# DEA              NaN
# MACD             NaN
# CROSS_JC    0.000000
# CROSS_SC    0.000000
# ZERO        0.000000
# Name: (2019-08-21 00:00:00, 000001), dtype: float64
# LONG 000001 20000
# backtest: Settle!
# 0
# 609726.1260319296
# 0
# 2019-08-21 00:00:00 000002
# DIFF        0.444936
# DEA              NaN
# MACD             NaN
# CROSS_JC    0.000000
# CROSS_SC    0.000000
# ZERO        0.000000
# Name: (2019-08-21 00:00:00, 000002), dtype: float64
# SHORT 000002 0
# backtest: Settle!
# 0
# 609726.1260319296
# 0
# 2019-08-22 00:00:00 000001
# DIFF       -0.146707
# DEA              NaN
# MACD             NaN
# CROSS_JC    0.000000
# CROSS_SC    0.000000
# ZERO        0.000000
# Name: (2019-08-22 00:00:00, 000001), dtype: float64
# SHORT 000001 30000
# backtest: Settle!
# 1
# 752647.2510319296
# 1
# 2019-08-22 00:00:00 000002
# DIFF        0.418707
# DEA         0.176562
# MACD        0.484290
# CROSS_JC    0.000000
# CROSS_SC    0.000000
# ZERO        0.000000
# Name: (2019-08-22 00:00:00, 000002), dtype: float64
# SHORT 000002 0
# backtest: Settle!
# 0
# 752647.2510319296
# 0
# 2019-08-23 00:00:00 000001
# DIFF       -0.151156
# DEA         0.100858
# MACD       -0.504027
# CROSS_JC    0.000000
# CROSS_SC    1.000000
# ZERO        0.000000
# Name: (2019-08-23 00:00:00, 000001), dtype: float64
# SHORT 000001 20000
# backtest: Settle!
# 6
# 898964.1260319296
# 6
# 2019-08-23 00:00:00 000002
# DIFF        0.402100
# DEA         0.168353
# MACD        0.467494
# CROSS_JC    1.000000
# CROSS_SC    0.000000
# ZERO        0.000000
# Name: (2019-08-23 00:00:00, 000002), dtype: float64
# LONG 000002 0
# backtest: Settle!
# 8
# 618492.3922051861
# 8
# 2019-08-26 00:00:00 000001
# DIFF       -0.201978
# DEA         0.087327
# MACD       -0.578610
# CROSS_JC    0.000000
# CROSS_SC    1.000000
# ZERO        0.000000
# Name: (2019-08-26 00:00:00, 000001), dtype: float64
# LONG 000001 10000
# backtest: Settle!
# 4
# 475956.7672051861
# 4
# 2019-08-26 00:00:00 000002
# DIFF        0.324961
# DEA         0.138361
# MACD        0.373200
# CROSS_JC    1.000000
# CROSS_SC    0.000000
# ZERO        0.000000
# Name: (2019-08-26 00:00:00, 000002), dtype: float64
# SHORT 000002 10000
# backtest: Settle!
# 3
# 750710.1954289061
# 3
# 2019-08-27 00:00:00 000001
# DIFF       -0.263509
# DEA         0.053311
# MACD       -0.633641
# CROSS_JC    0.000000
# CROSS_SC    1.000000
# ZERO        0.000000
# Name: (2019-08-27 00:00:00, 000001), dtype: float64
# SHORT 000001 20000
# backtest: Settle!
# 8
# 893631.3204289061
# 8
# 2019-08-27 00:00:00 000002
# DIFF        0.285619
# DEA         0.101910
# MACD        0.367418
# CROSS_JC    1.000000
# CROSS_SC    0.000000
# ZERO        0.000000
# Name: (2019-08-27 00:00:00, 000002), dtype: float64
# LONG 000002 0
# backtest: Settle!
# 1
# 617737.0184598691
# 1
# 2019-08-28 00:00:00 000001
# DIFF       -0.301326
# DEA         0.018322
# MACD       -0.639296
# CROSS_JC    0.000000
# CROSS_SC    1.000000
# ZERO        0.000000
# Name: (2019-08-28 00:00:00, 000001), dtype: float64
# SHORT 000001 10000
# backtest: Settle!
# 5
# 760258.6434598691
# 5
# 2019-08-28 00:00:00 000002
# DIFF        0.262065
# DEA         0.068483
# MACD        0.387166
# CROSS_JC    1.000000
# CROSS_SC    0.000000
# ZERO        0.000000
# Name: (2019-08-28 00:00:00, 000002), dtype: float64
# SHORT 000002 10000
# backtest: Settle!
# 2
# 1036050.8370076865
# 2
# 2019-08-29 00:00:00 000001
# DIFF       -0.333284
# DEA        -0.013722
# MACD       -0.639124
# CROSS_JC    0.000000
# CROSS_SC    1.000000
# ZERO        0.000000
# Name: (2019-08-29 00:00:00, 000001), dtype: float64
# SHORT 000001 0
# backtest: Settle!
# 6
# 1036050.8370076865
# 6
# 2019-08-29 00:00:00 000002
# DIFF        0.194541
# DEA         0.028695
# MACD        0.331692
# CROSS_JC    1.000000
# CROSS_SC    0.000000
# ZERO        0.000000
# Name: (2019-08-29 00:00:00, 000002), dtype: float64
# LONG 000002 0
# backtest: Settle!
# 3
# 765878.3248607826
# 3
# 2019-08-30 00:00:00 000001
# DIFF       -0.384948
# DEA        -0.055243
# MACD       -0.659409
# CROSS_JC    0.000000
# CROSS_SC    1.000000
# ZERO        0.000000
# Name: (2019-08-30 00:00:00, 000001), dtype: float64
# SHORT 000001 0
# backtest: Settle!
# 4
# 765878.3248607826
# 4
# 2019-08-30 00:00:00 000002
# DIFF        0.145111
# DEA        -0.014705
# MACD        0.319633
# CROSS_JC    1.000000
# CROSS_SC    0.000000
# ZERO        0.000000
# Name: (2019-08-30 00:00:00, 000002), dtype: float64
# SHORT 000002 10000
# Wall time: 1.68 s

# %%
t.indicators.data['MACD']
# Out:
# date        code
# 2019-08-01  000001         NaN
#             000002         NaN
# 2019-08-02  000001         NaN
#             000002         NaN
# 2019-08-05  000001         NaN
#             000002         NaN
# 2019-08-06  000001         NaN
#             000002         NaN
# 2019-08-07  000001         NaN
#             000002         NaN
# 2019-08-08  000001         NaN
#             000002         NaN
# 2019-08-09  000001         NaN
#             000002         NaN
# 2019-08-12  000001         NaN
#             000002         NaN
# 2019-08-13  000001         NaN
#             000002         NaN
# 2019-08-14  000001         NaN
#             000002         NaN
# 2019-08-15  000001         NaN
#             000002         NaN
# 2019-08-16  000001         NaN
#             000002         NaN
# 2019-08-19  000001         NaN
#             000002         NaN
# 2019-08-20  000001         NaN
#             000002         NaN
# 2019-08-21  000001         NaN
#             000002         NaN
# 2019-08-22  000001         NaN
#             000002    0.484290
# 2019-08-23  000001   -0.504027
#             000002    0.467494
# 2019-08-26  000001   -0.578610
#             000002    0.373200
# 2019-08-27  000001   -0.633641
#             000002    0.367418
# 2019-08-28  000001   -0.639296
#             000002    0.387166
# 2019-08-29  000001   -0.639124
#             000002    0.331692
# 2019-08-30  000001   -0.659409
#             000002    0.319633
# Name: MACD, dtype: float64

# %%
# t.indicators.xs('000001', level=1).loc['2019-08-01':'2019-08-05']
# print (t.indicators.loc[pd.IndexSlice['2019-08-01':'2019-08-05',:],:])

# t.get_ind(date = ['2019-08-01','2019-08-05'])
t.indicators.loc['2019-08-01':'2019-08-09']
# ind = t.indicators.xs('000001', level=1)
# idx = ind.index.get_loc('2019-08-05')
# ind.iloc[idx:idx+0+1]
# ind.iloc[idx-2:idx+1]
t.get_ind_offset('000001','2019-08-20',-1)

# %%
t.indicators.data

# %%
Risk = QA.QA_Risk(t.acc_portfolio)
fig = Risk.assets.plot()
fig.plot()

# %%
fig = Risk.plot_assets_curve()
fig.plot()
# Risk.message

# %%
pr=QA.QA_Performance(t.accounts['portfolio'])
pr.pnl_fifo
pr.plot_pnlmoney()
pr.plot_pnlratio()
pr.message
