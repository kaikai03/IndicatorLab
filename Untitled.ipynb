# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

# %%
import Ju_units as ju
import time

# %%
x = np.linspace(-np.pi, np.pi, 50)
y = np.sin(x)
plt.plot(x, y)

# %%
@ju.stream_print_wrap
def test1():
    for i in range(3):
        ju.stream_print(str(time.clock()))
        time.sleep(1)

test1()
# Out:
# '2.0098016'

# %%
def test2():
    for i in range(3):
        ju.stream_print(str(time.clock()))
        time.sleep(1)

test2()
# Out:
# ---------------------------------------------------------------------------
# AssertionError                            Traceback (most recent call last)
# <ipython-input-5-066f04732e32> in <module>()
#       5         time.sleep(1)
#       6
# ----> 7 test2()
#
# <ipython-input-5-066f04732e32> in test2()
#       2 def test2():
#       3     for i in range(3):
# ----> 4         ju.stream_print(str(time.clock()))
#       5         time.sleep(1)
#       6
#
# D:\PyProjects\IndicatorLab\Ju_units.py in stream_print(str)
#       7
#       8 def stream_print(str):
# ----> 9     assert display_handle!=None,"需要先stream_print_on"
#      10     display_handle.update(str)
#      11
#
# AssertionError: 需要先stream_print_on
