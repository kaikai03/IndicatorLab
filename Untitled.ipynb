# %%
import numpy as np
import pandas as pd
from scipy.optimize import minimize
import scipy.stats as st
import statsmodels.api as sm

from sklearn import linear_model

# %%
def make_half_life_ind(period):
    return np.exp(np.log(0.5)/period)

def weight_half_life(T,period):
    '''半衰期权重生成：T 当前轮数， period：半衰期长度'''
    return round(np.power(make_half_life_ind(50), 50),8)

def neutralize(factor:pd.Series, data, categorical:list=None, logarithmetics:list=None):
    '''市中性化：'''    
    X = data    
    # 对数化
    if not logarithmetics is None:
        X[logarithmetics] = np.log(X[logarithmetics])
    # 哑变量
    if not categorical is None:
        X = pd.get_dummies(X,categorical)

    model = linear_model.LinearRegression().fit(X, factor)
    factor_fitted = factor - model.predict(X)
    neutralize_factor = factor - factor_fitted

    return neutralize_factor

def get_rank_ic(factor, ret_forward):
    """
       计算因子的信息系数
    输入：
        factor: 因子值, multiIndex[date,code]
        ret_forward: 下一期的股票收益率,multiIndex[date,code]
    返回：
        DataFrame:包含['IC']和['pValue']
    """
    
    assert len(factor.index.get_level_values(1).unique()) > 4, '股票数量必须大于4，否则没啥意义啊'
    
    common_index = factor.index.get_level_values(0).unique().intersection(ret_forward.index.get_level_values(0).unique())
    ic_data = pd.DataFrame(index=common_index, columns=['IC','pValue'])

    # 计算相关系数
    for dt in ic_data.index:
        tmp_factor = factor[dt]
        tmp_ret = ret_forward[dt]
   
        df = pd.DataFrame({'factor':tmp_factor, 'ret_f':tmp_ret},index=tmp_factor.index.intersection(tmp_ret.index).to_list())
        print(dt)
        print(df)
        df = df[~pd.isnull(df['factor'])][~pd.isnull(df['ret_f'])]
        if len(df) < 5:
            continue

        ic, p_value = st.spearmanr(df['factor'], df['ret_f'])   # 计算秩相关系数RankIC
        ic_data['IC'][dt] = ic
        ic_data['pValue'][dt] = p_value
    return ic_data

# %%
import QUANTAXIS as QA
import base.JuUnits as u
from QUANTAXIS.QAUtil.QAParameter import MARKET_TYPE, RUNNING_ENVIRONMENT, ORDER_DIRECTION
data = QA.QA_quotation(['000001','000002', '000004', '000005', '000006'], '2021-03-01', '2021-03-16', source=QA.DATASOURCE.MONGO,
                               frequence='day', market=MARKET_TYPE.STOCK_CN, 
                               output=QA.OUTPUT_FORMAT.DATASTRUCT)
data.data
# Out:
#                     open   high    low  close     volume        amount
# date       code
# 2021-03-01 000001  21.54  21.68  21.18  21.45  1125386.0  2.408051e+09
#            000002  33.10  33.71  32.29  33.35  1280834.0  4.229751e+09
#            000004  18.95  19.45  18.86  19.12    22289.0  4.263078e+07
#            000005   2.15   2.28   2.15   2.23   112902.0  2.500548e+07
#            000006   5.16   5.23   5.14   5.19    63842.0  3.308206e+07
# 2021-03-02 000001  21.62  22.15  21.26  21.65  1473425.0  3.196537e+09
#            000002  33.00  34.60  32.90  33.29  1220149.0  4.110316e+09
#            000004  19.10  19.12  18.68  18.99    18720.0  3.531048e+07
#            000005   2.21   2.27   2.20   2.22    79642.0  1.775290e+07
#            000006   5.20   5.27   5.10   5.12   101953.0  5.260255e+07
#            000002  31.30  31.88  31.25  31.44   619315.0  1.951738e+09
#            000004  17.17  17.25  16.80  17.06    12922.0  2.193616e+07
#            000005   2.22   2.29   2.19   2.27   124237.0  2.801571e+07
#            000006   5.19   5.35   5.17   5.29   160059.0  8.452907e+07
# 2021-03-16 000001  21.60  22.11  21.27  21.66   939684.0  2.038471e+09
#            000002  31.49  33.16  31.30  32.90  1205423.0  3.904736e+09
#            000004  17.04  17.42  16.90  17.41    14224.0  2.445380e+07
#            000005   2.27   2.34   2.25   2.34   174688.0  4.030392e+07
#            000006   5.29   5.44   5.24   5.44   208545.0  1.121074e+08

# %%
# get_rank_ic()
forward_return = data.close.groupby(level=1, group_keys=False).apply(lambda x:((x-x.shift(1))/x.shift(1)).shift(-1))
test_factor = data.volume

get_rank_ic(test_factor, forward_return)

# test_factor['2021-03-01']
# forward_return['2021-03-01']
# test_factor.index.test_factor.index.levels

# test_factor.index.get_level_values(0).unique().intersection(forward_return.index.get_level_values(0).unique())

# test_factor.index.get_level_values(1).unique()
# len(test_factor.index.get_level_values(1).unique())
# Out:
# 2021-03-01 00:00:00
#            factor     ret_f
# 000001  1125386.0  0.009324
# 000002  1280834.0 -0.001799
# 000004    22289.0 -0.006799
# 000005   112902.0 -0.004484
# 000006    63842.0 -0.013487
# 2021-03-02 00:00:00
#            factor     ret_f
# 000001  1473425.0  0.062818
# 000002  1220149.0  0.006308
# 000004    18720.0 -0.010532
# 000005    79642.0  0.009009
# 000006   101953.0  0.009766
# 2021-03-03 00:00:00
#            factor     ret_f
# 000001  1919635.0 -0.003911
# 000002  1164840.0 -0.024179
# 000004    17151.0 -0.034593
# 000005    63518.0  0.008929
# 000006    65130.0 -0.003868
# 2021-03-04 00:00:00
#            factor     ret_f
# 000001  1213579.0 -0.025305
# 000002  1292857.0 -0.035179
# 000004    22377.0  0.022051
# 000005    77642.0  0.030973
# 000006    73555.0  0.005825
# 2021-03-05 00:00:00
#            factor     ret_f
# 000001   880171.0 -0.033124
# 000002  1303283.0 -0.010780
# 000004    21334.0 -0.008630
# 000005   125695.0 -0.034335
# 000006    76700.0 -0.005792
# 2021-03-08 00:00:00
#           factor     ret_f
# 000001  993774.0 -0.034722
# 000002  771959.0 -0.005769
# 000004   27727.0 -0.047878
# 000005  120190.0 -0.022222
# 000006   77597.0 -0.009709
# 2021-03-09 00:00:00
#            factor     ret_f
# 000001  1361895.0 -0.021583
# 000002   943414.0 -0.010638
# 000004    25748.0 -0.020571
# 000005    96450.0 -0.036364
# 000006   115140.0 -0.019608
# 2021-03-10 00:00:00
#            factor     ret_f
# 000001  1149416.0  0.042647
# 000002   877517.0  0.014989
# 000004    15733.0  0.019837
# 000005    75885.0  0.023585
# 000006    71964.0  0.024000
# 2021-03-11 00:00:00
#            factor     ret_f
# 000001  1048659.0  0.009873
# 000002   742679.0  0.010915
# 000004    14813.0 -0.016590
# 000005    72742.0  0.013825
# 000006    81602.0  0.009766
# 2021-03-12 00:00:00
#           factor     ret_f
# 000001  697200.0  0.005587
# 000002  901959.0 -0.001588
# 000004   15652.0 -0.007563
# 000005   76827.0  0.031818
# 000006   89833.0  0.023211
# 2021-03-15 00:00:00
#           factor     ret_f
# 000001  958748.0  0.002778
# 000002  619315.0  0.046438
# 000004   12922.0  0.020516
# 000005  124237.0  0.030837
# 000006  160059.0  0.028355
# 2021-03-16 00:00:00
#            factor  ret_f
# 000001   939684.0    NaN
# 000002  1205423.0    NaN
# 000004    14224.0    NaN
# 000005   174688.0    NaN
# 000006   208545.0    NaN
#              IC    pValue
# date
# 2021-03-01  0.8  0.104088
# 2021-03-02  0.7   0.18812
# 2021-03-03  0.1  0.872889
# 2021-03-04 -0.7   0.18812
# 2021-03-05 -0.5  0.391002
# 2021-03-08  0.3  0.623838
# 2021-03-09  0.2   0.74706
# 2021-03-10  0.3  0.623838
# 2021-03-11  0.3  0.623838
# 2021-03-12    0         1
# 2021-03-15 -0.1  0.872889
# 2021-03-16  NaN       NaN

# %%
a = pd.DataFrame({'fa':[15,12,31,47,11,60,150],'ma':[10000,120000,30000,640000,110000,240000,500000],'hy':["5","5","1","2","3","4","5"]}, index=["a","b","c","d","e","f","g"])
# dummy = sm.categorical(a.hy, drop=True)
# pd.get_dummies(a,['hy'])

# a = pd.get_dummies(a,['hy'])
# y = a['fa']
# X = a.iloc[:,1:]
# model = sm.OLS(y,X)
# results = model.fit()
# y_fitted = results.fittedvalues
# y_ = y - y_fitted
# y_
# a

#neutralize(a['fa'], a.iloc[:,1:],categorical=['hy'],logarithmetics=['ma'])
a.shift(-1)
st.spearmanr(a['fa'], a['ma'])
# Out:
# SpearmanrResult(correlation=1.0, pvalue=0.0)

# %%
weight_half_life(50,50)
# Out:
# 0.5

# %%
##############l拉格朗日
 
#目标函数：
def func(args):
    fun = lambda x: 60 - 10*x[0] - 4*x[1] + x[0]**2 + x[1]**2 - x[0]*x[1]
    #fun = lambda x: 10 - x[0]**2 - x[1]**2
    return fun
 
#约束条件，包括等式约束和不等式约束
def con(args):
    cons = [{'type': 'eq', 'fun': lambda x: x[0]+x[1]-8}]
    #cons = [{'type': 'ineq', 'fun': lambda x: x[1]-x[0]**2},
    #        {'type': 'eq', 'fun': lambda x: x[0]+x[1]}]
    return cons 
 

args = ()
args1 = ()
cons = con(args1)
x0 = np.array((2.0, 1.0))  #设置初始值，初始值的设置很重要，很容易收敛到另外的极值点中，建议多试几个值

#求解#
res = minimize(func(args), x0, method='SLSQP', constraints=cons)
print(res.success)
print("x1=",res.x[0],";  x2=",res.x[1])
print("最优解为：",res.fun)
# Out:
# True
# x1= 4.999999943481969 ;  x2= 3.000000056518032
# 最优解为： 17.000000000000007
